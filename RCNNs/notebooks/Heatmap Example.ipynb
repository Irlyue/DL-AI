# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
a = np.zeros((10, 10))

for i in range(10):
    for j in range(10):
        a[i, j] = 1 - (i**2+j**2)**0.5 / (10*2**0.5)

# %%
plt.imshow(a, cmap='hot', interpolation='bilinear')
plt.show()
